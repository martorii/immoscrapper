# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from decouple import config
import pandas as pd
import numpy as np
from backend.utils import *
from sklearn import linear_model
import statsmodels.api as sm

pd.options.display.max_columns = None
pd.set_option('display.max_colwidth', None)

# %%
from scrapper.database.mysql import Database
db = Database(config('db_host'), config('db_port'), config('db_database'), config('db_user'), config('db_password'))
db.test_connection()
# Out:
# Test: Database connection.
# Success: Connection to database.
# True

# %%
table = 'properties'
df = get_sqlalchemy_table_to_pandas(table, db)

# %%
# Get only interesting columns
df = drop_unnecessary_columns(df)
# Delete properties without price
df = df[df.price>0]

# %%
df = df[df.portal=='pisos']

# %%
# Assume NaNs are E by energy_certificate
df.energy_certificate.fillna('E', inplace=True)

# %%
# Floor and built-up area
df['floor_area'] = df[['usable_floor_area','floor_area']].min(axis=1)
df['built_up_area'] = df[['built_up_area', 'floor_area']].max(axis=1)
df.floor_area.fillna(df.built_up_area, inplace=True)
df = df[df.floor_area.notna()]
df.drop(columns=['usable_floor_area', 'built_up_area'], inplace=True)

# %%
# Delete weird floors
df = df[df.floor<=10]

# Study only locations in Barcelona
df = df[df.location.str.contains('Barcelona')]

# %%
# if 'Barcelona Capital' in text:
#     # Get neighborhood
#     pattern = r'^[^\(]+'
#     neighborhood = re.search(pattern, text)
#     # Get district
#     pattern = r'(?<=\()(.*?)(?=\.)'
#     district = re.search(pattern, text)
#     # City
#     city = 'Barcelona Capital'
# return

# %%
# Drop where no n_rooms
df = df[df.n_rooms.notna()]

# %%
# No bathrooms --> 1
df.loc[(df.n_bathrooms.isna()),'n_bathrooms']=1

# %%
# Replace garage nans with 0
df.garage.fillna(0, inplace=True)

# %%
# Improve flooring
df.drop(columns=['flooring'], inplace=True)

# %%
# Condition
df = df[df.condition.notna()]
condition_dict = {
    'good': ['in good condition', 'good'],
    'remodelled': ['remodelled'],
    'new': ['brand new'],
    'very good': ['almost new', 'very good'],
    'to reform': ['to reform']
}
df['condition'] = df['condition'].apply(map_from_value_to_key, mapper=condition_dict)

# %%
# Heating
heating_dict = {
    'natural gas': ['natural gas', 'gas natural', 'yes', 'central', 'gasoil'],
    'electric': ['electricity', 'electricidad']
}
df['heating'] = df['heating'].apply(map_from_value_to_key, mapper=heating_dict)
df.heating.fillna('No', inplace=True)

# %%
# Air conditioning
air_conditioning_dict = {
    'cold and heat': ['cold and heat', 'frío-calor'],
    'cold': ['cold', 'yes']
}
df['air_conditioning'] = df['air_conditioning'].apply(map_from_value_to_key, mapper=air_conditioning_dict)
df.air_conditioning.fillna('No', inplace=True)

# %%
# Antiquity
antiquity_dict = {
    '50+': ['more than 50 years', '50 to 70 years', '70 to 100 years'],
    '30-50': ['between 30 and 50 years', '30 to 50 years'],
    '20-30': ['between 20 and 30 years', '20 to 30 years'],
    '10-20': ['between 10 and 20 years', '10 to 20 years'],
    '5-10': ['between 5 and 10 years'],
    '0-5': ['less than 5 years', '1 to 5 years']
}
df['antiquity'] = df['antiquity'].apply(map_from_value_to_key, mapper=antiquity_dict)
df.antiquity.fillna('10-20', inplace=True)

# %%
# Facing
df.loc[(df.facing.isna()),'facing']='West'
df = df[df.facing.isin(['South', 'East', 'Southeast', 'Southwest', 'West', 'North', 'Northeast', 'Northwest'])]

# %%
# Swimming pool
swimming_pool_dict = {
    'communal': ['communal'],
    'own': ['own', 'con piscina']
}
df['swimming_pool'] = df['swimming_pool'].apply(map_from_value_to_key, mapper=swimming_pool_dict)
df.swimming_pool.fillna('No', inplace=True)

# %%
# Garden
garden_dict = {
    'communal': ['communal'],
    'own': ['own', 'private', 'yes']
}
df['garden'] = df['garden'].apply(map_from_value_to_key, mapper=garden_dict)
df.garden.fillna('No', inplace=True)

# %%
# Delete portal
df.drop(columns=['portal'], inplace=True)

# %%
numerical_features = df.select_dtypes(include=np.number).columns.tolist()
categorical_features = [feature for feature in df.columns if feature not in numerical_features]

# %%
df = get_dummies_from_categorical(categorical_features, df)

# %%
X = df.drop(columns=['price'])
Y = df[['price']]
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
display(model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.597
# Method:                 Least Squares   F-statistic:                     10.50
# Date:                Thu, 15 Apr 2021   Prob (F-statistic):           1.35e-79
# Time:                        21:37:53   Log-Likelihood:                -9012.9
# No. Observations:                 656   AIC:                         1.823e+04
# Df Residuals:                     553   BIC:                         1.869e+04
# Df Model:                         102
# Covariance Type:            nonrobust
# =====================================================================================================================================================================
#                                                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                              3.966e+04   3.31e+04      1.197      0.232   -2.54e+04    1.05e+05
# n_rooms                                                                                           -2.866e+04   7677.299     -3.734      0.000   -4.37e+04   -1.36e+04
# n_bathrooms                                                                                        7.428e+04   2.21e+04      3.362      0.001    3.09e+04    1.18e+05
# floor                                                                                              3934.3996   5553.442      0.708      0.479   -6974.021    1.48e+04
# equipped_kitchen                                                                                  -3443.9965   2.44e+04     -0.141      0.888   -5.13e+04    4.44e+04
# garage                                                                                              126.1198    561.687      0.225      0.822    -977.182    1229.422
# own_balcony                                                                                       -2.176e-10   4.19e-10     -0.520      0.603   -1.04e-09    6.05e-10
# terrace                                                                                            1.788e+04   2.52e+04      0.709      0.478   -3.16e+04    6.74e+04
# floor_area                                                                                         4611.5780    365.816     12.606      0.000    3893.019    5330.137
# location_Can Baró (District Horta-Guinardó. Barcelona Capital)                                     1.889e+04   1.15e+05      0.165      0.869   -2.06e+05    2.44e+05
# location_Canyelles (District Nou Barris. Barcelona Capital)                                       -7.829e+04   1.46e+05     -0.537      0.592   -3.65e+05    2.08e+05
# location_Ciutat Meridiana (District Nou Barris. Barcelona Capital)                                -5.848e+04   1.29e+05     -0.452      0.652   -3.13e+05    1.96e+05
# location_Diagonal Mar-El Front Marítim del Poblenou (District Sant Martí. Barcelona Capital)       4390.6949   7.27e+04      0.060      0.952   -1.38e+05    1.47e+05
# location_Eixample (Barcelona Capital)                                                              9.299e+04   2.48e+05      0.375      0.708   -3.94e+05     5.8e+05
# location_El Baix Guinardó (District Horta-Guinardó. Barcelona Capital)                             2.529e+04   7.57e+04      0.334      0.739   -1.23e+05    1.74e+05
# location_El Barri Gòtic (District Ciutat Vella. Barcelona Capital)                                 5.387e+04   5.37e+04      1.003      0.316   -5.16e+04    1.59e+05
# location_El Besòs-El Maresme (District Sant Martí. Barcelona Capital)                             -6.926e+04   9.52e+04     -0.728      0.467   -2.56e+05    1.18e+05
# location_El Bon Pastor (District Sant Andreu. Barcelona Capital)                                   -1.26e+05   1.04e+05     -1.216      0.225    -3.3e+05    7.76e+04
# location_El Camp d'en Grassot-Gràcia Nova (District Gràcia. Barcelona Capital)                      3.82e+04   7.35e+04      0.519      0.604   -1.06e+05    1.83e+05
# location_El Camp de l'Arpa del Clot (District Sant Martí. Barcelona Capital)                       2.881e+04   9.56e+04      0.301      0.763   -1.59e+05    2.17e+05
# location_El Carmel (District Horta-Guinardó. Barcelona Capital)                                   -5.234e+04   7.66e+04     -0.684      0.495   -2.03e+05    9.81e+04
# location_El Clot (District Sant Martí. Barcelona Capital)                                         -5654.8157   6.61e+04     -0.086      0.932   -1.36e+05    1.24e+05
# location_El Coll (District Gràcia. Barcelona Capital)                                             -4.903e+04   1.25e+05     -0.394      0.694   -2.94e+05    1.96e+05
# location_El Congrés-Els Indians (District Sant Andreu. Barcelona Capital)                         -3.312e+04   9.42e+04     -0.351      0.725   -2.18e+05    1.52e+05
# location_El Fort Pienc (District Eixample. Barcelona Capital)                                      7655.2974    5.7e+04      0.134      0.893   -1.04e+05     1.2e+05
# location_El Guinardó (District Horta-Guinardó. Barcelona Capital)                                 -3.958e+04   6.16e+04     -0.642      0.521   -1.61e+05    8.15e+04
# location_El Parc-La Llacuna del Poblenou (District Sant Martí. Barcelona Capital)                  4.487e+04   9.63e+04      0.466      0.642   -1.44e+05    2.34e+05
# location_El Poble-sec (District Sants-Montjuïc. Barcelona Capital)                                -8177.9938   8.31e+04     -0.098      0.922   -1.71e+05    1.55e+05
# location_El Poblenou (District Sant Martí. Barcelona Capital)                                      7.137e+04   5.65e+04      1.264      0.207   -3.95e+04    1.82e+05
# location_El Putxet-El Farró (District Sarrià-Sant Gervasi. Barcelona Capital)                      3.597e+04   7.36e+04      0.489      0.625   -1.09e+05     1.8e+05
# location_El Raval (District Ciutat Vella. Barcelona Capital)                                      -1.964e+04   4.56e+04     -0.431      0.667   -1.09e+05    6.99e+04
# location_El Turó de la Peira-Can Peguera (District Nou Barris. Barcelona Capital)                 -1.973e+05   1.42e+05     -1.391      0.165   -4.76e+05    8.12e+04
# location_Horta (District Horta-Guinardó. Barcelona Capital)                                       -4.293e+04   7.31e+04     -0.587      0.557   -1.87e+05    1.01e+05
# location_Hostafrancs (District Sants-Montjuïc. Barcelona Capital)                                   1.84e+04   1.23e+05      0.150      0.881   -2.23e+05     2.6e+05
# location_L'Antiga Esquerra de l'Eixample (District Eixample. Barcelona Capital)                    1.495e+05   5.99e+04      2.496      0.013    3.19e+04    2.67e+05
# location_La Barceloneta (District Ciutat Vella. Barcelona Capital)                                 2.367e+05   1.73e+05      1.366      0.172   -1.04e+05    5.77e+05
# location_La Bordeta (District Sants-Montjuïc. Barcelona Capital)                                  -5.636e+04    9.5e+04     -0.593      0.553   -2.43e+05     1.3e+05
# location_La Dreta de l'Eixample (District Eixample. Barcelona Capital)                             3.128e+05    4.5e+04      6.949      0.000    2.24e+05    4.01e+05
# location_La Font d'en Fargues (District Horta-Guinardó. Barcelona Capital)                        -7.333e+04   1.47e+05     -0.499      0.618   -3.62e+05    2.15e+05
# location_La Font de la Guatlla (District Sants-Montjuïc. Barcelona Capital)                       -1.053e+05   9.29e+04     -1.133      0.258   -2.88e+05    7.73e+04
# location_La Guineueta (District Nou Barris. Barcelona Capital)                                     7.807e+04   2.54e+05      0.307      0.759   -4.22e+05    5.78e+05
# location_La Marina del Port-Parc de Montjuïc (District Sants-Montjuïc. Barcelona Capital)         -9.191e+04   6.77e+04     -1.357      0.175   -2.25e+05    4.12e+04
# location_La Marina del Prat Vermell-Zona Franca-Port (District Sants-Montjuïc. Barcelona Capital) -9.862e+04   1.25e+05     -0.792      0.429   -3.43e+05    1.46e+05
# location_La Maternitat-Sant Ramon (District Les Corts. Barcelona Capital)                          -4.34e+04   9.55e+04     -0.454      0.650   -2.31e+05    1.44e+05
# location_La Nova Esquerra de l'Eixample (District Eixample. Barcelona Capital)                     3.024e+04   4.41e+04      0.686      0.493   -5.63e+04    1.17e+05
# location_La Prosperitat (District Nou Barris. Barcelona Capital)                                  -3.129e+04   7.34e+04     -0.426      0.670   -1.76e+05    1.13e+05
# location_La Sagrada Família (District Eixample. Barcelona Capital)                                 4550.5291   4.96e+04      0.092      0.927   -9.29e+04    1.02e+05
# location_La Sagrera (District Sant Andreu. Barcelona Capital)                                     -1.739e+04   1.01e+05     -0.173      0.863   -2.15e+05    1.81e+05
# location_La Salut (District Gràcia. Barcelona Capital)                                            -1.023e+05   1.75e+05     -0.585      0.559   -4.46e+05    2.41e+05
# location_La Teixonera (District Horta-Guinardó. Barcelona Capital)                                -8.329e+04   1.08e+05     -0.773      0.440   -2.95e+05    1.28e+05
# location_La Trinitat Vella (District Sant Andreu. Barcelona Capital)                               -2.87e+05   2.45e+05     -1.169      0.243   -7.69e+05    1.95e+05
# location_La Vall d'Hebron (District Horta-Guinardó. Barcelona Capital)                             7.673e+04   2.56e+05      0.300      0.764   -4.26e+05    5.79e+05
# location_La Verneda-La Pau (District Sant Martí. Barcelona Capital)                               -5.121e+04   1.24e+05     -0.414      0.679   -2.94e+05    1.92e+05
# location_La Vila Olímpica del Poblenou (District Sant Martí. Barcelona Capital)                    8768.3001   1.43e+05      0.061      0.951   -2.72e+05     2.9e+05
# location_La Vila de Gràcia (District Gràcia. Barcelona Capital)                                    7.188e+04   7.44e+04      0.967      0.334   -7.42e+04    2.18e+05
# location_Les Corts (District Les Corts. Barcelona Capital)                                         1.734e+05   6.16e+04      2.816      0.005    5.24e+04    2.94e+05
# location_Les Tres Torres (District Sarrià-Sant Gervasi. Barcelona Capital)                         1.886e+05   1.04e+05      1.812      0.071   -1.59e+04    3.93e+05
# location_Montbau (District Horta-Guinardó. Barcelona Capital)                                      1757.3107   2.49e+05      0.007      0.994   -4.87e+05    4.91e+05
# location_Navas (District Sant Andreu. Barcelona Capital)                                          -9.317e+04   9.49e+04     -0.982      0.326   -2.79e+05    9.31e+04
# location_Pedralbes (District Les Corts. Barcelona Capital)                                         2.271e+05   1.05e+05      2.153      0.032    1.99e+04    4.34e+05
# location_Porta (District Nou Barris. Barcelona Capital)                                           -9.234e+04   1.24e+05     -0.747      0.455   -3.35e+05     1.5e+05
# location_Provençals del Poblenou (District Sant Martí. Barcelona Capital)                         -2.152e+04   1.24e+05     -0.174      0.862   -2.64e+05    2.21e+05
# location_Roquetes (District Nou Barris. Barcelona Capital)                                        -6.434e+04   1.25e+05     -0.514      0.608    -3.1e+05    1.82e+05
# location_Sant Andreu (District Sant Andreu. Barcelona Capital)                                    -4.303e+04   1.04e+05     -0.415      0.679   -2.47e+05    1.61e+05
# location_Sant Antoni (District Eixample. Barcelona Capital)                                       -3951.8188   7.94e+04     -0.050      0.960    -1.6e+05    1.52e+05
# location_Sant Gervasi-Galvany (District Sarrià-Sant Gervasi. Barcelona Capital)                    1.527e+05   6.04e+04      2.527      0.012     3.4e+04    2.71e+05
# location_Sant Gervasi-La Bonanova (District Sarrià-Sant Gervasi. Barcelona Capital)                1.505e+05   9.87e+04      1.525      0.128   -4.33e+04    3.44e+05
# location_Sant Martí de Provençals (District Sant Martí. Barcelona Capital)                        -3.508e+04   1.04e+05     -0.339      0.735   -2.39e+05    1.68e+05
# location_Sant Pere-Santa Caterina-La Ribera (District Ciutat Vella. Barcelona Capital)              1.02e+05   6.69e+04      1.524      0.128   -2.95e+04    2.33e+05
# location_Sants (District Sants-Montjuïc. Barcelona Capital)                                       -5.209e+04   6.96e+04     -0.749      0.454   -1.89e+05    8.46e+04
# location_Sants-Badal (District Sants-Montjuïc. Barcelona Capital)                                 -9948.8513   8.33e+04     -0.119      0.905   -1.74e+05    1.54e+05
# location_Sarrià (District Sarrià-Sant Gervasi. Barcelona Capital)                                  2.316e+05   1.01e+05      2.297      0.022    3.35e+04     4.3e+05
# location_Vallbona (District Nou Barris. Barcelona Capital)                                        -3.347e+05   2.49e+05     -1.343      0.180   -8.24e+05    1.55e+05
# location_Vallcarca-Els Penitents (District Gràcia. Barcelona Capital)                              3.318e+04   8.93e+04      0.371      0.710   -1.42e+05    2.09e+05
# location_Verdun (District Nou Barris. Barcelona Capital)                                          -2.682e+04   1.12e+05     -0.240      0.810   -2.46e+05    1.93e+05
# location_Vilapicina-La Torre Llobeta (District Nou Barris. Barcelona Capital)                     -3.287e+04   1.13e+05     -0.291      0.771   -2.54e+05    1.89e+05
# energy_certificate_A                                                                               6.182e+04   6.52e+04      0.948      0.343   -6.62e+04     1.9e+05
# energy_certificate_B                                                                               -8.68e+04   8.42e+04     -1.030      0.303   -2.52e+05    7.87e+04
# energy_certificate_C                                                                               1.403e+04   6.35e+04      0.221      0.825   -1.11e+05    1.39e+05
# energy_certificate_D                                                                               6.453e+04   3.97e+04      1.624      0.105   -1.35e+04    1.43e+05
# energy_certificate_E                                                                               3521.4677   2.55e+04      0.138      0.890   -4.65e+04    5.36e+04
# energy_certificate_F                                                                               -2.01e+04   4.17e+04     -0.482      0.630   -1.02e+05    6.18e+04
# energy_certificate_G                                                                               2664.6839   3.71e+04      0.072      0.943   -7.01e+04    7.54e+04
# antiquity_0-5                                                                                      8.776e+04   7.62e+04      1.151      0.250    -6.2e+04    2.38e+05
# antiquity_10-20                                                                                    -1.78e+04   3.57e+04     -0.499      0.618   -8.79e+04    5.23e+04
# antiquity_20-30                                                                                   -7569.9717    5.8e+04     -0.131      0.896   -1.21e+05    1.06e+05
# antiquity_30-50                                                                                    5531.4118   3.87e+04      0.143      0.887   -7.06e+04    8.16e+04
# antiquity_5-10                                                                                     1794.7288   1.44e+05      0.012      0.990   -2.81e+05    2.85e+05
# antiquity_50+                                                                                     -3.006e+04   3.58e+04     -0.840      0.401      -1e+05    4.02e+04
# condition_good                                                                                    -7304.3725    1.9e+04     -0.384      0.701   -4.47e+04    3.01e+04
# condition_new                                                                                      2.345e+04   3.55e+04      0.660      0.510   -4.63e+04    9.32e+04
# condition_remodelled                                                                                1.09e+04   2.36e+04      0.461      0.645   -3.55e+04    5.73e+04
# condition_to reform                                                                                1.261e+04   2.84e+04      0.443      0.658   -4.33e+04    6.85e+04
# heating_No                                                                                         2.944e+04   2.22e+04      1.327      0.185   -1.41e+04     7.3e+04
# heating_electric                                                                                  -2.611e+04    3.2e+04     -0.816      0.415    -8.9e+04    3.67e+04
# heating_natural gas                                                                                3.633e+04   2.19e+04      1.656      0.098   -6763.687    7.94e+04
# air_conditioning_No                                                                                8615.6517   1.94e+04      0.445      0.657   -2.94e+04    4.66e+04
# air_conditioning_cold                                                                             -2.246e+04   2.39e+04     -0.941      0.347   -6.93e+04    2.44e+04
# air_conditioning_cold and heat                                                                      5.35e+04    2.5e+04      2.138      0.033    4351.448    1.03e+05
# facing_East                                                                                        7984.4263   3.63e+04      0.220      0.826   -6.34e+04    7.94e+04
# facing_North                                                                                      -4.329e+04   6.95e+04     -0.623      0.533    -1.8e+05    9.32e+04
# facing_Northeast                                                                                   2.072e+04   4.87e+04      0.426      0.670   -7.49e+04    1.16e+05
# facing_Northwest                                                                                  -2253.3436   7.52e+04     -0.030      0.976    -1.5e+05    1.45e+05
# facing_South                                                                                       3.018e+04    3.6e+04      0.838      0.403   -4.06e+04    1.01e+05
# facing_Southeast                                                                                   3.795e+04   3.91e+04      0.972      0.332   -3.88e+04    1.15e+05
# facing_Southwest                                                                                  -3.231e+04    5.2e+04     -0.621      0.535   -1.34e+05    6.98e+04
# facing_West                                                                                        2.068e+04   2.31e+04      0.895      0.371   -2.47e+04    6.61e+04
# swimming_pool_No                                                                                  -1.529e+05   6.48e+04     -2.360      0.019    -2.8e+05   -2.56e+04
# swimming_pool_communal                                                                            -9755.2608   7.89e+04     -0.124      0.902   -1.65e+05    1.45e+05
# swimming_pool_own                                                                                  2.023e+05   1.37e+05      1.474      0.141   -6.73e+04    4.72e+05
# garden_No                                                                                         -3599.7729   4.08e+04     -0.088      0.930   -8.37e+04    7.65e+04
# garden_communal                                                                                    2.151e+04   5.92e+04      0.363      0.717   -9.48e+04    1.38e+05
# garden_own                                                                                         2.174e+04    6.3e+04      0.345      0.730   -1.02e+05    1.46e+05
# ==============================================================================
# Omnibus:                     1166.997   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1035044.330
# Skew:                          11.382   Prob(JB):                         0.00
# Kurtosis:                     196.260   Cond. No.                     1.10e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.36e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
results = pd.DataFrame(model.params, columns=['coef']).reset_index().rename(columns={'index': 'name'})
results = results[results.name.str.contains('location')].sort_values('coef')
results
# def get_most_expensive_districts(model):
#     model.coef
# Out:
#                                                                                  name  \
# 72                         location_Vallbona (District Nou Barris. Barcelona Capital)
# 50               location_La Trinitat Vella (District Sant Andreu. Barcelona Capital)
# 31  location_El Turó de la Peira-Can Peguera (District Nou Barris. Barcelona Capital)
# 17                   location_El Bon Pastor (District Sant Andreu. Barcelona Capital)
# 39        location_La Font de la Guatlla (District Sants-Montjuïc. Barcelona Capital)
# ..                                                                                ...
# 56         location_Les Tres Torres (District Sarrià-Sant Gervasi. Barcelona Capital)
# 59                         location_Pedralbes (District Les Corts. Barcelona Capital)
# 71                  location_Sarrià (District Sarrià-Sant Gervasi. Barcelona Capital)
# 35                 location_La Barceloneta (District Ciutat Vella. Barcelona Capital)
# 37             location_La Dreta de l'Eixample (District Eixample. Barcelona Capital)
#
#              coef
# 72 -334651.130791
# 50 -287002.264523
# 31 -197339.630475
# 17 -126007.953978
# 39 -105321.246926
# ..            ...
# 56  188573.128151
# 59  227084.459422
# 71  231571.869315
# 35  236656.780782
# 37  312803.291997
#
# [67 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor()
regr.fit(X, Y)
# Out:
# C:\Users\kerik\Anaconda\envs\immoscrapper\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor()

# %%
# Out:
# <bound method BaseEstimator.get_params of RandomForestRegressor()>
